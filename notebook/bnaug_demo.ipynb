# %% [markdown]
# <a href="https://colab.research.google.com/github/sagorbrur/bnaug/blob/main/notebook/bnaug_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bangla Text Augmentation (bnaug)

# %%
# !pip install bnaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bnaug
#   Downloading bnaug-1.0.0-py3-none-any.whl (4.0 kB)
# Collecting bnlp-toolkit==3.2.0
#   Downloading bnlp_toolkit-3.2.0-py3-none-any.whl (19 kB)
# Collecting transformers==4.24.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 5.4 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from bnlp-toolkit==3.2.0->bnaug) (3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from bnlp-toolkit==3.2.0->bnaug) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from bnlp-toolkit==3.2.0->bnaug) (4.64.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from bnlp-toolkit==3.2.0->bnaug) (1.7.3)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 67.5 MB/s
# Requirement already satisfied: wasabi in /usr/local/lib/python3.7/dist-packages (from bnlp-toolkit==3.2.0->bnaug) (0.10.1)
# Collecting gensim==4.0.1
#   Downloading gensim-4.0.1-cp37-cp37m-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 1.3 MB/s
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.0.1->bnlp-toolkit==3.2.0->bnaug) (5.2.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 39.9 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 47.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.24.0->bnaug) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0->bnaug) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.24.0->bnaug) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.24.0->bnaug) (3.10.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->bnlp-toolkit==3.2.0->bnaug) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->bnlp-toolkit==3.2.0->bnaug) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.24.0->bnaug) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.24.0->bnaug) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.24.0->bnaug) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.24.0->bnaug) (1.24.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->bnlp-toolkit==3.2.0->bnaug) (0.8.10)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 44.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->bnlp-toolkit==3.2.0->bnaug) (1.15.0)
# Installing collected packages: python-crfsuite, tokenizers, sklearn-crfsuite, sentencepiece, huggingface-hub, gensim, transformers, bnlp-toolkit, bnaug
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed bnaug-1.0.0 bnlp-toolkit-3.2.0 gensim-4.0.1 huggingface-hub-0.11.0 python-crfsuite-0.9.8 sentencepiece-0.1.97 sklearn-crfsuite-0.3.6 tokenizers-0.13.2 transformers-4.24.0

# %%
# !wget https://huggingface.co/sagorsarker/bangla_word2vec/resolve/main/bangla_word2vec_gen4.zip
# !wget https://huggingface.co/sagorsarker/bangla-glove-vectors/resolve/main/bn_glove.300d.zip

# !unzip bangla_word2vec_gen4.zip
# !unzip bn_glove.300d.zip

# !rm -rf bangla_word2vec_gen4.zip
# !rm -rf bn_glove.300d.zip
# Out:
# --2022-11-21 11:58:52--  https://huggingface.co/sagorsarker/bangla_word2vec/resolve/main/bangla_word2vec_gen4.zip
# Resolving huggingface.co (huggingface.co)... 34.200.207.32, 54.159.186.195, 2600:1f18:147f:e800:7a81:37eb:4345:da2, ...
# Connecting to huggingface.co (huggingface.co)|34.200.207.32|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos
__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2022-11-21 11:58:56--  https://cdn-lfs.huggingface.co/repos/aa/54/aa548a31e1afcb96a938d527a7a3914d612289d4eec18ddd467509e7f2f37969/5d66200bc461365e98afa1ff172c40ebef5fd64e8c8188744a9fe3673148ce11?response-content-disposition=attachment%3B%20filename%3D%22bn_glove.300d.zip%22&Expires=1669291137&Policy=..._&Signature=kthA5h9PtH4Z~ZaJQXPLadfNZ72hDfb878AVwI0MLc7D-1Y2hsf11SE~pjm6SH-JEcyNk-RqzIQU7zglAI8AitRxgCB4fJDr-JOH~o2VBEAaZRLnFSBI55vkO4G7VlrzPlcwAin8SbuLy1akont~KTmGKB2v~wK5vxcLWBOV7XeUvAsu1YzmRJoqm359YQTIYUpZstyv9gWq5101dK-2ANfjcXw-h-YS1s0L42The7idxe33EK85c7SMvnxy52fiqEyYsTd1AliMbzfMJhNBXi~rLbULMtOd4Lu0nYIyx70~5n1xUZQrl3hZCwmERMhVT0XF0CXFwddpEtAbzxxZmA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.156.83.35, 108.156.83.97, 108.156.83.76, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.156.83.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145929792 (139M) [application/zip]
# Saving to: ‘bn_glove.300d.zip’
#
# bn_glove.300d.zip   100%[===================>] 139.17M  51.6MB/s    in 2.7s
#
# 2022-11-21 11:58:59 (51.6 MB/s) - ‘bn_glove.300d.zip’ saved [145929792/145929792]
#
# Archive:  bangla_word2vec_gen4.zip
#    creating: bangla_word2vec/
#   inflating: bangla_word2vec/README.md
#   inflating: bangla_word2vec/bnwiki_word2vec.model
#   inflating: bangla_word2vec/bnwiki_word2vec.model.syn1neg.npy
#   inflating: bangla_word2vec/bnwiki_word2vec.model.wv.vectors.npy
#   inflating: bangla_word2vec/bnwiki_word2vec.vector
#    creating: bangla_word2vec/evaluations/
#   inflating: bangla_word2vec/evaluations/evaluation.json
# Archive:  bn_glove.300d.zip
#   inflating: bn_glove.300d.txt

# %% [markdown]
# ## Token Replacement

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "আমি ঢাকায় বাস করি।"
output = tokr.masking_based(text, sen_n=5)
print(output)
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.7/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# Downloading:   0%|          | 0.00/491 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/660M [00:00<?, ?B/s]
# Some weights of the model checkpoint at sagorsarker/bangla-bert-base were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# ['আমি এখানে বাস করি ।', 'আমি সেখানে বাস করি ।', 'আমি বাস করি ।', 'আমি বাংলাদেশে বাস করি ।', 'আমি ওখানে বাস করি ।', 'আমি ঢাকায বাস করি ।', 'আমি ঢাকায বাস করি?', 'আমি ঢাকায বাস করি!', 'আমি ঢাকায বাস করি না', 'আমি ঢাকায বাস করি', 'আমি ঢাকায বাস করি ।', 'আমি ঢাকায বাস করি?', 'আমি ঢাকায বাস করি!', 'আমি ঢাকায বাস করি না', 'আমি ঢাকায বাস করি', 'আমি ঢাকায বাস করি ।', 'আমি ঢাকায ভ্রমণ করি ।', 'আমি ঢাকায কাজ করি ।', 'আমি ঢাকায ব্যবহার করি ।', 'আমি ঢাকায পালন করি ।', 'আমি ঢাকায বাস করি ।', 'আমি ঢাকায বাস করছি ।', 'আমি ঢাকায বাস করেছি ।', 'আমি ঢাকায বাস করতাম ।', 'আমি ঢাকায বাস করিনি ।']

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "আমি ঢাকায় বাস করি।"
model = "bangla_word2vec/bnwiki_word2vec.model"
output = tokr.word2vec_based(text, model=model, sen_n=5, word_n=5)
print(output)
# Out:
# "Key 'ঢাকায়' not present"
# "Key 'ঢাকায়' not present"
# "Key 'ঢাকায়' not present"
# ['আমি ঢাকায় বাস করিএবং', 'আমি ঢাকায় বাস করি.', 'আমি ঢাকায় বাস করিযাতে', 'আমি ঢাকায় বাস করিযা', 'আমি ঢাকায় বাস করিযেখানে', 'আমি ঢাকায় বসবাস করি।', 'আমি ঢাকায় যাতায়াত করি।', 'আমি ঢাকায় চলাচল করি।', 'আমি ঢাকায় ঘোরাফেরা করি।', 'আমি ঢাকায় ভ্রমণ করি।']

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "আমি ঢাকায় বাস করি।"
vector = "bn_glove.300d.txt"
output = tokr.glove_based(text, vector_path=vector, sen_n=5, word_n=5)
print(output)
# Out:
# 'ঢাকায়'
# 'ঢাকায়'
# '।'
# ['আমি ঢাকায় বাস করি।', 'আমার ঢাকায় বাস করি।', 'করি ঢাকায় বাস করি।', 'আমাকে ঢাকায় বাস করি।', 'আমরা ঢাকায় বাস করি।', 'আমি ঢাকায় বাস করি।', 'আমি ঢাকায় বাস আমরা।', 'আমি ঢাকায় বাস করব।', 'আমি ঢাকায় বাস করবো।', 'আমি ঢাকায় বাস করিনি।']

# %% [markdown]
# ## Back Translation

# %%
from bnaug.sentence import BackTranslation

bt = BackTranslation()
text = "বাংলা ভাষা আন্দোলন তদানীন্তন পূর্ব পাকিস্তানে সংঘটিত একটি সাংস্কৃতিক ও রাজনৈতিক আন্দোলন। "
output = bt.get_augmented_sentences(text)
print(output)
# Out:
# Downloading:   0%|          | 0.00/766 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/766 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 128 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# [' বাংলা ভাষা আন্দোলন পূর্ব পাকিস্তানে সংঘটিত একটি রাজনৈতিক ও সাংস্কৃতিক আন্দোলন।']

# %% [markdown]
# ## Text Generation

# %%
from bnaug.sentence import TextGeneration

tg = TextGeneration()
text = "বিমানটি যখন মাটিতে নামার জন্য এয়ারপোর্টের কাছাকাছি আসছে, তখন ল্যান্ডিং গিয়ারের খোপের ঢাকনাটি খুলে যায়।"
output = tg.parapharse_generation(text)
print(output)
# Out:
# Downloading:   0%|          | 0.00/707 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# [' প্লেনটা এয়ারপোর্টের কাছে অবতরণ করার সময়, ল্যান্ডিং গিয়ার প্যানেলের ঢাকনাটা খুলে দেওয়া']
